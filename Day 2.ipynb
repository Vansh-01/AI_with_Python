# %% [markdown]
# # Set

# %%
- It is collection of different elements
- It is an unordered collection of data type 
- It consist of unquie element
- We can perform mathematical operations on set 
- It is enclosed in curly braces
- Each element is seperated by comma

# %%
a = {10,20,30,40.5}
print(a)
print(type(a))
# Out:
# {40.5, 10, 20, 30}
# <class 'set'>

# %%
a = {10,20,30,40,10,20,30,40,50,60,60}
print(a)
# Out:
# {50, 20, 40, 10, 60, 30}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
a = {10,20,30,40,50,60}

a.add(100)
a
# Out:
# {10, 20, 30, 40, 50, 60, 100}

# %%
a = {10,20,30,40,50,60}
a.clear()
a
# Out:
# set()

# %%
a = {10,20,30,40,50,60}
b = a.copy()
b
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
a = {10,20,30,40}
b = {10,50,60}
a.difference(b)
# Out:
# {20, 30, 40}

# %%
b.difference(a)
# Out:
# {50, 60}

# %%
a = {10,20,30,40}
b = {10,50,60}
a.union(b)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
a.intersection(b)
# Out:
# {10}

# %%
a = {10,20,30,40}
a.pop()
a
# Out:
# {10, 20, 30}

# %%
a.pop()
a
# Out:
# {20, 30}

# %%
a = {10,20,30,40}
a.pop(0)
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_27565/4225582325.py in <module>
#       1 a = {10,20,30,40}
# ----> 2 a.pop(0)
#       3 a
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
a = {10,20,30,40}
a.remove(10)
a
# Out:
# {20, 30, 40}

# %%
a.remove(100)
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_27565/2171473417.py in <module>
# ----> 1 a.remove(100)
#       2 a
#
# KeyError: 100

# %% [markdown]
# # Dictionary

# %%
- It is collection of key value pair
- It is enclosed in curly braces
- It consist of unique keys
- Each item is seperated by comma
- Each key value pair is seperated colan

# %%
a = {1:'Hemant', 2:'Hema', 3:'Rohit'}
print(a)
print(type(a))
# Out:
# {1: 'Hemant', 2: 'Hema', 3: 'Rohit'}
# <class 'dict'>

# %%
a = {1:'Hemant', 2:'Hema', 3:'Rohit', 1:'Prateek', 1:'Suraj'}
print(a)
print(type(a))
# Out:
# {1: 'Suraj', 2: 'Hema', 3: 'Rohit'}
# <class 'dict'>

# %%
a = {1:'Hemant', 2:'Hemant', 3:'Hemant'}
print(a)
print(type(a))
# Out:
# {1: 'Hemant', 2: 'Hemant', 3: 'Hemant'}
# <class 'dict'>

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
a = {1:'Hemant', 2:'Hema', 3:'Rohit'}
a.clear()
a
# Out:
# {}

# %%
a = {1:'Hemant', 2:'Hema', 3:'Rohit'}
a.items()
# Out:
# dict_items([(1, 'Hemant'), (2, 'Hema'), (3, 'Rohit')])

# %%
a.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
a.values()
# Out:
# dict_values(['Hemant', 'Hema', 'Rohit'])

# %%
a.get(1)
# Out:
# 'Hemant'

# %%
a = {1:'Hemant', 2:'Hema', 3:'Rohit'}
a.pop(1)
a
# Out:
# {2: 'Hema', 3: 'Rohit'}

# %% [markdown]
# # Statements

# %% [markdown]
# # if else elif

# %%
a = int(input("enter the number : ")) 
if a>10:
    print('A is greater than 10')
if a<10:
    print('A is lesser than 10 ')
if a ==10:
    print('A is 10')
# Out:
# enter the number : 10
# A is 10

# %%
a = int(input("enter the number : ")) 
if a>10:
    print('A is greater than 10')
if a ==10:
    print('A is 10')
else:
    print('A is lesser than 10 ')
# Out:
# enter the number : 12
# A is greater than 10
# A is lesser than 10

# %%
a = int(input("enter the number : ")) 
if a>10:
    print('A is greater than 10')
elif a ==10:
    print('A is 10')
else:
    print('A is lesser than 10 ')
# Out:
# enter the number : 8
# A is lesser than 10

# %%
# WAP to find the greatest number out of two number
# WAP to find the wheather the given number is even or odd
# WAP to find the wheather the given number is positive, negative or zero
# WAP to find the the greatest number out of three numbers

# %% [markdown]
# # Shorthand if else statement

# %%
a,b = 10,20 
print(a) if a>b else print(b)
# Out:
# 20

# %% [markdown]
# # For and while loop

# %%
a = 'python'
for i in a:
    print(a)
# Out:
# python
# python
# python
# python
# python
# python

# %%
a = 'python'
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 'python'
for i in range(1,len(a)):
    print('a')
# Out:
# a
# a
# a
# a
# a

# %%
a = 'Hemant'
for i in a:
    print(i)
# Out:
# H
# e
# m
# a
# n
# t

# %%
a = [10,20,30,40,50,60]
for i in a:
    if i == 60:
        print(i)
# Out:
# 60

# %%
a = [10,20,30,40,50,60]
for i in a:
    print(i)
    if i == 60:
        break
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
a = [10,20,30,40,50,60]
for i in a:  
    if i == 60:
        break
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
a = [10,20,30,40,50,60]
for i in a:  
    if i == 60:
        break
        print(i)

# %%
a = [10,20,30,40,50,60]
for i in a:  
    if i == 60:
        continue
        print(i)

# %%
a = [10,20,30,40,50,60]
for i in a:
    continue
    if i == 60:
        print(i)

# %%
a = [10,20,30,40,50,60]
for i in a:
    print(a)
    if i == 60:
        print(i)
        continue
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# 60

# %%
a = [10,20,30,40,50,60]
for i in a:
    print(a)
    pass
    if i == 60:
        print(i)
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# 60

# %%
a = 10 
if a> 10:
    pass

# %% [markdown]
# # While

# %%
a = 10 
while a>9:
    print('python')
    a = a - 1
# Out:
# python

# %% [markdown]
# # Functions

# %%
- user defined functions
- self defined function
- lambda function

# %% [markdown]
# # User Defined function

# %%
a = 10 
b = 20 
c = a+b
print(c)
# Out:
# 30

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    return c

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    return c

abcd()
# Out:
# 30

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    print(c)

abcd()
# Out:
# 30

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    d = a-b
    return c
    return d

abcd()
# Out:
# (30, -10)

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    d = a-b
    print(c)
    print(d)

abcd()
# Out:
# 30
# -10

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    return c

def abc():
    a = 10 
    b = 20 
    d = a-b
    return d

abcd()
abc()
# Out:
# -10

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    print(c)

def abc():
    a = 10 
    b = 20 
    d = a-b
    print(d)

abcd()
abc()
# Out:
# 30
# -10

# %% [markdown]
# # Self defined function

# %%
import math as m

# %%
m.pow(3,2)
# Out:
# 9.0

# %%
m.sqrt(100)
# Out:
# 10.0

# %% [markdown]
# # Lambda function

# %%
x = lambda a,b :a+b
x(3,4)
# Out:
# 7

# %%
x = lambda a,b,c,d,e :a+b-c-d+e
x(3,4,5,4,3)
# Out:
# 1

# %%
def abcd(a,b):
    c = a+b
    return c

abcd(2,3)
# Out:
# 5

# %%
def abcd():
    a = 10 
    b = 20 
    c = a+b
    return c

def abc():
    a = 10 
    b = 20 
    d = a-b
    return d

abcd()
abc()

# %% [markdown]
# # Indexing

# %%
a = [10,20,30,40,50]
# positive 1, left to right
# negative -1, right to left

a[0]
# Out:
# 10

# %%
a[-5]
# Out:
# 10

# %%
a[1]
# Out:
# 20

# %%
a[-4]
# Out:
# 20

# %% [markdown]
# # Slicing

# %%
a = [10,20,30,40,50,60]
# a[::]
a[0:5+1:1]
# a[start: end+1:step]

# by default
# start - 0 
# end - goes upto the last
# step 1
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a = [10,20,30,40,50,60]
# [10,20]
# a[start:end+1:step]
a[0:1+1:1]
# Out:
# [10, 20]

# %%
# [40,60]
a[3:5+1:2]
# Out:
# [40, 60]

# %%
# [10,30,50]
a[0:4+1:2]
# Out:
# [10, 30, 50]

# %%
#[20,60]
a[1:5+1:4]
# Out:
# [20, 60]

# %%
# WAP to reverse your name using for loop
output - 'atpuG keetarP'

# WAP to reverse your name on the same 
position

output - 'keetarP atpuG'

# Create parameterized function for 
addition, sub, mul, div, floordivision and
modulus and i want all the answer of each function

# %%
# WAP to reverse your name using for loop
# output - 'atpuG keetarP'

a = "prateek gupta"
c = ""
for i in a:
    c = i + c
print(c)
# Out:
# atpug keetarp

# %%
keetarp  atpug

# %%
# Out:
# 30

# %%
a = 10 
b = 20 
print(a)
print(b)
# Out:
# 10
# 20

# %%
a = 10 
b = 20 
a
print(b)
# Out:
# 20

# %%
a = 10 
b = 20 
print(a)
b
# Out:
# 10
# 20

# %%
a = 10 
b = 20 
c = 30
print(a)
c
b
print(a)
# Out:
# 10
# 10
